# %%
import random
import numpy as np
from utils.treebank import RTE_dataset
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import time
import operator
from word2vec import *
from sgd import *

# Check Python Version
import sys
assert sys.version_info[0] == 3
assert sys.version_info[1] >= 5

# Reset the random seed to make sure that everyone gets the same results
random.seed(314)
dataset = RTE_dataset()
idx = dataset.sampleTokenIdx(0, 1000)
print(idx)  # 이 값들이 모두 < 24429 이면 OK
if np.max(idx) >= 24429:
    print("Error: The sampled indices exceed the vocabulary size. Please check your implementation.")
# Out:
# 📏 tmpSamplingFreq.shape = (24429,)
# 📏 self._samplingFreq.shape = (24429,)
# [ 5713    20  1007 16692  2010  8541 19656 12153  9021 19300  1974  6088
#     20 11596    64  1765 21367   125  7225   852 12142  6503  6267  3234
#  14639 21452  6594 19622 12887     4  5068  8912  6601 19659  3798  6562
#    128   226  1101 13845 17288  1021  6720    26 11479     6   991  1323
#  12768 20237    49   269 12121 13125 13245    26   169  7995  2278 22805
#  23902 14412  1233     1  2338  4744 10409 19830 23605    50   784 11866
#    223 21388 23594    86    15   561  3384  2308 24403  1658 10595 14332
#   2149 19168  8278   471  4960   142  2682 20351   241 16177  5239 14661
#    285  3822  7505  4111   638 10767    20   194  3888  5475    20  1504
#    901  2732 10932   216  9677  4932  8145  5723  5615  5870 11393 19728
#   1820 16139   555  3826  9046  2958 14736  1142 12105   582   851  1135
#   3150  4776 21487 15147 12113  3076 12452  4826 21048 19360    15  3789
# ...

# %%
print("🧠 max(word2Ind):", max(word2Ind.values()))
print("🧠 len(outsideVectors):", outsideVectors.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1180774/387180393.py in <module>
# ----> 1 print("🧠 max(word2Ind):", max(word2Ind.values()))
#       2 print("🧠 len(outsideVectors):", outsideVectors.shape[0])
#
# NameError: name 'word2Ind' is not defined

# %%
import random
import numpy as np
from utils.treebank import RTE_dataset
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import time
import operator
from word2vec import *
from sgd import *

# Check Python Version
import sys
assert sys.version_info[0] == 3
assert sys.version_info[1] >= 5

# Reset the random seed to make sure that everyone gets the same results
random.seed(314)
dataset = RTE_dataset()
import os

print("📂 Dataset path:", dataset.path)
data_file = os.path.join(dataset.path, "test.tsv")
if os.path.exists(data_file):
    print(f"✅ Data file exists: {data_file}")
else:
    print(f"❌ Data file missing: {data_file}")
# Out:
# 📂 Dataset path: utils/datasets/RTE
# ✅ Data file exists: utils/datasets/RTE/test.tsv
